# %%
import sys, time, cProfile, pstats, importlib, os, itertools
sys.path.insert(0,'/home/uq/apps/muq2inst/lib')
from concurrent.futures import ProcessPoolExecutor

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (40., 7.)
matplotlib.rcParams.update({'font.size': 22})
from mpl_toolkits.mplot3d import Axes3D

import pymuqUtilities as mu

import plotutil

from GaussianPosterior import GaussianMixture
from DeepTransportMap import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
mu.MultiIndexFactory.CreateAnisotropic([.812], .0001).Size()
# Out:
# 45

# %% [markdown]
# # Target densities for different depths L

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(5)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .2)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 201)
target = GaussianMixture(noiseLevels=[.1, .2], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.scatter(x, true_target, color='k', label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, label=str(len(temps)))

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  5
# [1]
# [0.5, 1]
# [0.25, 0.5, 1]
# [0.125, 0.25, 0.5, 1]
# [0.0625, 0.125, 0.25, 0.5, 1]

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(5)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .1)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 201)
target = GaussianMixture(noiseLevels=[.1, .2], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.scatter(x, true_target, color='k', label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, label=str(len(temps)))

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  7
# [1]
# [0.5, 1]
# [0.25, 0.5, 1]
# [0.125, 0.25, 0.5, 1]
# [0.0625, 0.125, 0.25, 0.5, 1]

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(5)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .05)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 201)
target = GaussianMixture(noiseLevels=[.1, .2], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.scatter(x, true_target, color='k', label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, label=str(len(temps)))

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  9
# [1]
# [0.5, 1]
# [0.25, 0.5, 1]
# [0.125, 0.25, 0.5, 1]
# [0.0625, 0.125, 0.25, 0.5, 1]

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(5)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .01)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 201)
target = GaussianMixture(noiseLevels=[.1, .2], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.scatter(x, true_target, color='k', label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, label=str(len(temps)))

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  13
# [1]
# [0.5, 1]
# [0.25, 0.5, 1]
# [0.125, 0.25, 0.5, 1]
# [0.0625, 0.125, 0.25, 0.5, 1]

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(10)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .1)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 201)
target = GaussianMixture(noiseLevels=[.1, .2], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.scatter(x, true_target, color='k', label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, label=str(len(temps)))

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  7
# [1]
# [0.5, 1]
# [0.25, 0.5, 1]
# [0.125, 0.25, 0.5, 1]
# [0.0625, 0.125, 0.25, 0.5, 1]
# [0.03125, 0.0625, 0.125, 0.25, 0.5, 1]
# [0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1]
# [0.0078125, 0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1]
# [0.00390625, 0.0078125, 0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1]
# [0.001953125, 0.00390625, 0.0078125, 0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1]

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(4)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .1)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 201)
target = GaussianMixture(noiseLevels=[.01, .02], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.scatter(x, true_target, color='k', label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, label=str(len(temps)))

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  7
# [1]
# [0.5, 1]
# [0.25, 0.5, 1]
# [0.125, 0.25, 0.5, 1]

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(0,8,2)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .1)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 501)
target = GaussianMixture(noiseLevels=[.02, .02], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.plot(x, true_target, color='k', lw=4, label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, lw=2, label=str(len(temps)-1))

multiset = mu.MultiIndexFactory.CreateAnisotropic([.812], .0001)
print('Number of multi-indices : ', multiset.Size())
deeptm = DeepTransportMap(1, target, [1.], multiset, 'wls')
density = [deeptm.density([xi]) for xi in x]
density /= np.sum(density)
ax1.plot(x, density, lw=4, label=r'L=0, $|\Lambda|=$'+str(multiset.Size()))

ax1.legend()
ax1.set_ylim([0, 1.5*np.max(true_target)])
plt.show()
# Out:
# Number of multi-indices :  7
# [1]
# [0.25, 0.5, 1]
# [0.0625, 0.125, 0.25, 0.5, 1]
# [0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1]
# Number of multi-indices :  45

# %%
temp_list = [[2**(-L+n) for n in range(L+1)] for L in range(0,8,2)]
multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .1)
print('Number of multi-indices : ', multiset.Size())

x = np.linspace(-1, 1, 501)
target = GaussianMixture(noiseLevels=[.04, .04], measurementList=[[-.4], [.5]])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.plot(x, true_target, color='k', lw=4, label='target')

for temps in temp_list :
    print(temps)
    deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')
    density = [deeptm.density([xi]) for xi in x]
    density /= np.sum(density)
    ax1.plot(x, density, lw=2, label=str(len(temps)-1))

multiset = mu.MultiIndexFactory.CreateAnisotropic([.812], .0001)
print('Number of multi-indices : ', multiset.Size())
deeptm = DeepTransportMap(1, target, [1.], multiset, 'wls')
density = [deeptm.density([xi]) for xi in x]
density /= np.sum(density)
ax1.plot(x, density, lw=4, label=r'L=0, $|\Lambda|=$'+str(multiset.Size()))

ax1.legend()
ax1.set_ylim([0, 1.5*np.max(true_target)])
plt.show()
# Out:
# Number of multi-indices :  7
# [1]
# [0.25, 0.5, 1]
# [0.0625, 0.125, 0.25, 0.5, 1]
# [0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1]
# Number of multi-indices :  45

# %% [markdown]
# # Bridging densities

# %%
x = np.linspace(-1, 1, 101)

L = 3
temps = [2**(-L+n) for n in range(L+1)]

target = GaussianPosterior(noise=.2, y_measurement=[.2])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)*2/len(x)

multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .01)
print('Number of multi-indices : ', multiset.Size())
deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.plot(x, true_target, 'k', linewidth = 4, label='target')


colors = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00']
for i in range(len(deeptm.maps)) :
    print(i, temps[i], len(deeptm.maps[:i+1]))
    density = [deeptm.maps[i].density([xi]) for xi in x]
    density /= np.sum(density)*2/len(x)
    
    ax1.plot(x, density, color=colors[i], label=r'$T$_'+str(i)+r'$_\# f_\mu$')
    
    #true_target = np.array([(target.Evaluate([np.array([xi])])[0][0])**(temps[i]) for xi in x])
    #true_target /= np.sum(true_target)*2/len(x)
    #ax1.scatter(x, true_target, color=colors[i])

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  13
# Constructed target k = 0 using temp t = 0.125
# Constructed target k = 1 using temp t = 0.25
# Constructed target k = 2 using temp t = 0.5
# Constructed target k = 3 using temp t = 1
# 0 0.125 1
# 1 0.25 2
# 2 0.5 3
# 3 1 4

# %% [markdown]
# # Tempered target densities

# %%
x = np.linspace(-1, 1, 101)

L = 3
temps = [2**(-L+n) for n in range(L+1)]

target = GaussianPosterior(noise=.2, y_measurement=[.2])
true_target = np.array([target.Evaluate([np.array([xi])])[0][0] for xi in x])
true_target /= np.sum(true_target)*2/len(x)

multiset = mu.MultiIndexFactory.CreateAnisotropic([.7], .05)
print('Number of multi-indices : ', multiset.Size())
deeptm = DeepTransportMap(1, target, temps, multiset, 'wls')

ax1 = plotutil.get_ax(plt.figure(), 1, 1, title='')
ax1.plot(x, true_target, 'k', linewidth = 4, label='target')


colors = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00']
for i in range(len(deeptm.maps)) :
    print(i, temps[i], len(deeptm.maps[:i+1]))
    density = [g_bar_x(deeptm.maps[:i+1], [xi]) for xi in x]
    density /= np.sum(density)*2/len(x)
    
    ax1.plot(x, density, color=colors[i], label=r'$\bar{T}$_'+str(i))
    
    true_target = np.array([(target.Evaluate([np.array([xi])])[0][0])**(temps[i]) for xi in x])
    true_target /= np.sum(true_target)*2/len(x)
    ax1.scatter(x, true_target, color=colors[i])

ax1.legend()
plt.show()
# Out:
# Number of multi-indices :  9
# Constructed target k = 0 using temp t = 0.125
# Constructed target k = 1 using temp t = 0.25
# Constructed target k = 2 using temp t = 0.5
# Constructed target k = 3 using temp t = 1
# 0 0.125 1
# 1 0.25 2
# 2 0.5 3
# 3 1 4

# %%
len(deeptm.maps)
# Out:
# 4

# %%
temps
# Out:
# [0.125, 0.25, 0.5, 1]

# %% [markdown]
# # DIRT to approximate 2D Gaussian

# %%
fig = plt.figure()
nbins = 201
x = np.linspace(-1, 1, nbins)

l2_errs = []
t_setup = []
t_eval  = []

ax1 = plotutil.get_ax(fig, 3, 1, title='Densities', projection='3d')

target   = GaussianPosterior(noise=.1, y_measurement=[0., 0.])
multiset = mu.MultiIndexFactory.CreateAnisotropic([.4, .4], .01)
print('Number of multi-indices : ', multiset.Size())

X, Y   = np.meshgrid(x, x)
points = np.vstack((X.flatten(), Y.flatten())).transpose()

true_target = np.array([target.Evaluate([xi])[0][0] for xi in points])
true_target /= np.sum(true_target)

levels = np.linspace(0, 0.1, 100)  #(z_min,z_max,number of contour),

ax1.plot_surface(X, Y, true_target.reshape((len(x), len(x))), rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))


for temps in [[2**(-L+n) for n in range(L+1)] for L in range(3)] :
    print(temps)
    start = time.process_time()
    deeptm = DeepTransportMap(2, target, temps, multiset)
    t_setup.append(time.process_time() - start)

    start = time.process_time()
    samples = np.array([deeptm.evaluate(np.random.uniform(low=-1, high=1, size=(2,))) for _ in range(10)])
    t_eval.append(time.process_time() - start)

    density = [deeptm.density(xi) for xi in points]
    density /= np.sum(density)

    offset = 10*len(temps)
    ax1.plot_surface(X, Y, offset+tm_hist.reshape((len(x), len(x))), rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))

    l2_errs.append(np.sqrt(np.sum((true_target - density)**2)))

depths = [len(temps) for temps in temp_list]
ax2 = plotutil.get_ax(fig, 3, 2, title='L2 Error', xlabel='DIRT depth')
ax2.set_xticks(depths)
ax2.plot(depths, l2_errs)

ax3 = plotutil.get_ax(fig, 3, 3, title='Runtime', xlabel='DIRT depth')
ax3.set_xticks(depths)
ax3.plot(depths, t_setup, label='setup time')
ax3.plot(depths, t_eval, label='eval time per 10 samples')

ax3.legend()
plt.show()
# Out:
# Number of multi-indices :  21
# [1]
# [0.5, 1]
# [0.25, 0.5, 1]
