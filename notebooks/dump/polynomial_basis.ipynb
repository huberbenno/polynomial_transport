# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.special import legendre

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import matplotlib
# %matplotlib inline

import pymuqUtilities as mu
import pymuqModeling_ as mm

import plotutil, approximation
# Out:
# <style>.container { width:100% !important; }</style>

# %%
m = 100
d = 1
samples = np.sin(np.random.uniform(low=-3*np.pi/2, high=np.pi/2, size=(10*m*int(np.log(m)),d)))
weights = np.pi/2*np.array([np.prod([np.sqrt(1-x**2) for x in samples[i,:]]) for i in range(samples.shape[0])])
print(samples)
print(weights)
# Out:
# [[ 0.98851732]
#  [-0.86146783]
#  [-0.97835764]
#  ...
#  [ 0.7765213 ]
#  [-0.920505  ]
#  [ 0.91886065]]
# [0.23735924 0.79766945 0.32503085 ... 0.98974463 0.61375848 0.61980826]

# %%
ax1 = plotutil.get_ax(plt.figure(figsize=(25,10)), 1, 1, title='')
hist = ax1.hist(samples, bins=20, density=True)
ax1.plot(x, true_target, lw=3, color='k', label='target')
plt.show()
